# %%
pip install -U kaleido

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Amazon Sale Report.csv')
df
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.fillna(0,inplace=True)

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            128976 non-null  object
#  12  Amount              128976 non-null  float64
#  13  ship-city           128976 non-null  object
#  14  ship-state          128976 non-null  object
# ...

# %%
df["ship-postal-code"] = df["ship-postal-code"].astype("int")

# %%
df["ship-postal-code"].dtype
# Out:
# dtype('int64')

# %%
df['Date']= pd.to_datetime(df['Date'])
# Out:
# /tmp/ipython-input-12-2691600196.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date']= pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.describe( )
# Out:
#                index                           Date            Qty  \
# count  128976.000000                         128976  128976.000000
# mean    64486.130427  2022-05-12 11:49:26.951991040       0.904401
# min         0.000000            2022-03-31 00:00:00       0.000000
# 25%     32242.750000            2022-04-20 00:00:00       1.000000
# 50%     64486.500000            2022-05-10 00:00:00       1.000000
# 75%     96730.250000            2022-06-04 00:00:00       1.000000
# max    128974.000000            2022-06-29 00:00:00      15.000000
# std     37232.897832                            NaN       0.313368
#
#               Amount  ship-postal-code       New  PendingS
# count  128976.000000     128976.000000  128976.0  128976.0
# mean      609.339491     463819.777587       0.0       0.0
# min         0.000000          0.000000       0.0       0.0
# 25%       413.000000     382421.000000       0.0       0.0
# 50%       583.000000     500033.000000       0.0       0.0
# ...

# %%
df.describe(include='object')
# Out:
#                    Order ID   Status Fulfilment Sales Channel  \
# count                128976   128976     128976        128976
# unique               120229       13          2             2
# top     403-4984515-8861958  Shipped     Amazon     Amazon.in
# freq                     12    77815      89713        128852
#
#        ship-service-level Category    Size Courier Status currency  ship-city  \
# count              128976   128976  128976         128976   128976     128976
# unique                  2        9      11              4        2       8949
# top             Expedited  T-shirt       M        Shipped      INR  BENGALURU
# freq                88630    50292   22373         109486   121176      11208
#
#          ship-state ship-country  fulfilled-by
# count        128976       128976        128976
# unique           70            2             2
# top     MAHARASHTRA           IN             0
# freq          22272       128941         89713

# %%
size = sns.countplot(x='Size', data=df, palette='Dark2')
for bars in size.containers:
    size.bar_label(bars)

plt.show()
# Out:
# /tmp/ipython-input-16-914308084.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   size = sns.countplot(x='Size', data=df, palette='Dark2')

# %% [markdown]
# # **Most of the People buy M size**

# %%
plt.figure(figsize=(10,6))
CourierStatus=sns.countplot(x='Courier Status',data=df, hue='Status', palette='Dark2')
for bars in CourierStatus.containers:
    CourierStatus.bar_label(bars)
plt.show()

# %% [markdown]
# # **We can see that majority of the orders are shipped through couriers**

# %%
df['Category'] = df['Category'].astype(str)
column_data=df['Category']
plt.figure(figsize=(10,6))
plt.hist(column_data,bins=20,edgecolor='Black', color='Purple')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Distribution of Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Most of the buyers purchase T-shirts**

# %%
check_B2B = df['B2B'].value_counts()
check_B2B

plt.pie(check_B2B,labels=check_B2B.index,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # **Maximum 99.3% of Buyers are Retailers and 0.7% are wholesalers**

# %%
x_data = df['Category']
y_data = df['Size']

plt.scatter(x_data,y_data,color='Green')
plt.xlabel('Category')
plt.ylabel('Size')
plt.title('Plotting of Category vs Size')
plt.show()

# %% [markdown]
# # **Most of the buyers buy T-Shirts**

# %%
top10_state = df['ship-state'].value_counts().head(10)
plt.figure(figsize=(15,8))
ship_state =sns.countplot(x='ship-state', data=df[df['ship-state'].isin(top10_state.index)], palette='Dark2')
for bars in ship_state.containers:
    ship_state.bar_label(bars)
plt.xticks(rotation=90)
plt.xlabel('Ship State')
plt.ylabel('Count')
plt.title('Top 10 Ship States')
plt.show()
# Out:
# /tmp/ipython-input-21-1128802236.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ship_state =sns.countplot(x='ship-state', data=df[df['ship-state'].isin(top10_state.index)], palette='Dark2')

# %% [markdown]
# # **Most of the buyers are from Maharashtra State**

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y", errors='coerce')  # Convert to datetime
df = df.dropna(subset=["Date"])  # Drop invalid dates
df["Month"] = df["Date"].dt.to_period("M")  # Extract month
df["ship-postal-code"] = df["ship-postal-code"].astype("Int64").astype("string")  # Postal code cleanup
df = df[df["Amount"].notna()]  # Drop rows without Amount

# %%
monthly_sales = df.groupby("Month").agg(
    Total_Orders=("Order ID", "nunique"),
    Total_Quantity=("Qty", "sum"),
    Total_Revenue=("Amount", "sum")
).reset_index()
monthly_sales["Month"] = monthly_sales["Month"].dt.to_timestamp()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_sales, x="Month", y="Total_Revenue", marker="o", color="blue")
plt.title("Monthly Revenue Trend")
plt.ylabel("Total Revenue (INR)")
plt.xlabel("Month")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fulfillment_stats = df.groupby("Fulfilment").agg(
    Orders=("Order ID", "nunique"),
    Revenue=("Amount", "sum")
).reset_index()

# %%
plt.figure(figsize=(8, 5))
Fulfilment = sns.barplot(data=fulfillment_stats, x="Fulfilment", y="Revenue", palette="coolwarm")
for bar in Fulfilment.containers:
    Fulfilment.bar_label(bar, fmt='%.2f')
plt.title("Revenue by Fulfillment Method")
plt.ylabel("Total Revenue (INR)")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-26-3266993906.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   Fulfilment = sns.barplot(data=fulfillment_stats, x="Fulfilment", y="Revenue", palette="coolwarm")

# %% [markdown]
# Amazon Sales Data Analysis – Key Insights
#
# **1. Revenue by Fulfillment Method**
#
# Amazon Fulfillment generated significantly more revenue ~54.3 million INR compared to Merchant Fulfillment ~24.3 million INR.
#
# **Conclusion:** Partnering with Amazon’s fulfillment services drives higher revenue, likely due to better logistics and trust.
#
# **2. Monthly Revenue Trend**
#
# Revenue increased sharply from March to April 2022, peaking in April (~30 million INR).
#
# Then it slightly decreased in May and June.
#
# **Conclusion:** April was the best performing month. This could relate to promotional events, seasonality, or marketing campaigns.
#
# **3. Top 10 Shipping States**
#
# Maharashtra leads by a large margin (22,272 shipments), followed by Karnataka (17,324) and Tamil Nadu (11,488).
#
# **Conclusion:** Focus marketing and logistics efforts on high-volume states like Maharashtra and Karnataka for better ROI.
#
# **4. Category vs. Size Distribution**
#
# A wide variety of product sizes (from XS to 6XL and Free Size) are available across multiple categories like T-shirts, Shirts, Shoes, Wallets, etc.
#
# **Conclusion:** Inventory is well-diversified in sizes, supporting a broad customer base with different needs.
#
# **5. B2B vs B2C Customers**
#
# 99.3% of buyers are Retail (B2C), while only 0.7% are B2B (wholesale).
#
# **Conclusion:** The customer base is primarily individual retail buyers. There's potential to expand into B2B sales.
#
# **6. Product Category Distribution**
#
# T-shirts and Shirts dominate the product categories, each with ~50,000 items sold.
#
# Blazers and Trousers follow with much lower volumes.
#
# **Conclusion:** Focus on optimizing T-shirt and Shirt inventory and explore marketing strategies to boost lower-selling categories.
#
# **7. Courier Status Distribution**
#
# Most orders are marked as “Shipped - Delivered to Buyer” (77,607) or “Shipped - Returned to Seller” (28,748).
#
# Other statuses (like damaged, cancelled, lost in transit) are very minimal.
#
# **Conclusion:** Delivery efficiency is high, but there is room to reduce return rates.
#
# **8. Size Distribution**
#
# The most common sizes are M (22,373), L (21,807), and XL (20,549).
#
# Rare sizes like 4XL, 5XL, XS have much lower counts.
#
# **Conclusion:** Inventory planning should prioritize mid-range sizes (M–XL), which cover the majority of the demand.
#
# # **Final Recommendation**
# 1.Strengthen Amazon Fulfillment partnerships.
#
# 2.Increase B2B targeting.
#
# 3.Prioritize inventory for T-shirts, Shirts, and sizes M–XL.
#
# 4.Consider exploring regional marketing strategies, especially in Maharashtra and Karnataka.
